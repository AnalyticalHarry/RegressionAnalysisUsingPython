# %% [markdown]
# ## GRADIENT DESCENT

# %% [markdown]
# ![image.png](attachment:da6aa395-9df6-41b3-96fb-cb8104903a45.png)

# %% [markdown]
# #### HEMANT THAPA

# %% [markdown]
# ##### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# ##### Example 1

# %%
data = [
    (1, 2),
    (2, 4),
    (3, 5),
    (4, 4)
]

# %%
m = 0.5
b = 0.5
learning_rate = 0.01
iterations = 50

# %%
iteration_list = []
mse_list = []
y_pred_list = []
dm_list = []
db_list = []
m_new_list = []
b_new_list = []

# %%
for iteration in range(iterations):
    #predicted values
    y_pred = [m * xi + b for xi, _ in data]
    #MSE
    mse = sum([(yi - ypi)**2 for (_, yi), ypi in zip(data, y_pred)]) / len(data)
    
    #derivatives
    dm = (-2/len(data)) * sum([xi * (yi - ypi) for (xi, yi), ypi in zip(data, y_pred)])
    db = (-2/len(data)) * sum([yi - ypi for (_, yi), ypi in zip(data, y_pred)])
    
    #Update m and b
    m_new = m - learning_rate * dm
    b_new = b - learning_rate * db
    
    #append values to lists
    iteration_list.append(iteration)
    mse_list.append(mse)
    y_pred_list.append(y_pred)
    dm_list.append(dm)
    db_list.append(db)
    m_new_list.append(m_new)
    b_new_list.append(b_new)
    
    #iteration details
    print(f"Iteration {iteration + 1}: MSE = {mse:.4f}, m = {m:.4f}, b = {b:.4f}, dm = {dm:.4f}, db = {db:.4f}")
    
    #Update m and b for the next iteration
    m = m_new
    b = b_new
# Out:
# Iteration 1: MSE = 4.6250, m = 0.5000, b = 0.5000, dm = -10.5000, db = -4.0000
# Iteration 2: MSE = 3.4678, m = 0.6050, b = 0.5400, dm = -8.7250, db = -3.3950
# Iteration 3: MSE = 2.6643, m = 0.6923, b = 0.5740, dm = -7.2465, db = -2.8908
# Iteration 4: MSE = 2.1063, m = 0.7647, b = 0.6029, dm = -6.0150, db = -2.4707
# Iteration 5: MSE = 1.7187, m = 0.8249, b = 0.6276, dm = -4.9892, db = -2.1205
# Iteration 6: MSE = 1.4492, m = 0.8748, b = 0.6488, dm = -4.1348, db = -1.8287
# Iteration 7: MSE = 1.2617, m = 0.9161, b = 0.6671, dm = -3.4231, db = -1.5854
# Iteration 8: MSE = 1.1312, m = 0.9503, b = 0.6829, dm = -2.8304, db = -1.3825
# Iteration 9: MSE = 1.0401, m = 0.9786, b = 0.6967, dm = -2.3367, db = -1.2133
# Iteration 10: MSE = 0.9764, m = 1.0020, b = 0.7089, dm = -1.9255, db = -1.0722
# Iteration 11: MSE = 0.9318, m = 1.0213, b = 0.7196, dm = -1.5831, db = -0.9545
# Iteration 12: MSE = 0.9003, m = 1.0371, b = 0.7291, dm = -1.2979, db = -0.8563
# Iteration 13: MSE = 0.8780, m = 1.0501, b = 0.7377, dm = -1.0604, db = -0.7742
# Iteration 14: MSE = 0.8621, m = 1.0607, b = 0.7454, dm = -0.8626, db = -0.7057
# Iteration 15: MSE = 0.8506, m = 1.0693, b = 0.7525, dm = -0.6980, db = -0.6485
# Iteration 16: MSE = 0.8422, m = 1.0763, b = 0.7590, dm = -0.5608, db = -0.6006
# Iteration 17: MSE = 0.8359, m = 1.0819, b = 0.7650, dm = -0.4467, db = -0.5606
# Iteration 18: MSE = 0.8310, m = 1.0864, b = 0.7706, dm = -0.3517, db = -0.5270
# Iteration 19: MSE = 0.8272, m = 1.0899, b = 0.7759, dm = -0.2726, db = -0.4989
# Iteration 20: MSE = 0.8241, m = 1.0926, b = 0.7809, dm = -0.2067, db = -0.4753
# Iteration 21: MSE = 0.8216, m = 1.0947, b = 0.7856, dm = -0.1520, db = -0.4554
# Iteration 22: MSE = 0.8193, m = 1.0962, b = 0.7902, dm = -0.1064, db = -0.4387
# Iteration 23: MSE = 0.8173, m = 1.0973, b = 0.7945, dm = -0.0685, db = -0.4246
# Iteration 24: MSE = 0.8155, m = 1.0979, b = 0.7988, dm = -0.0370, db = -0.4127
# Iteration 25: MSE = 0.8138, m = 1.0983, b = 0.8029, dm = -0.0108, db = -0.4026
# Iteration 26: MSE = 0.8122, m = 1.0984, b = 0.8069, dm = 0.0110, db = -0.3940
# Iteration 27: MSE = 0.8107, m = 1.0983, b = 0.8109, dm = 0.0290, db = -0.3867
# Iteration 28: MSE = 0.8092, m = 1.0980, b = 0.8148, dm = 0.0440, db = -0.3804
# Iteration 29: MSE = 0.8077, m = 1.0976, b = 0.8186, dm = 0.0564, db = -0.3750
# Iteration 30: MSE = 0.8063, m = 1.0970, b = 0.8223, dm = 0.0667, db = -0.3703
# Iteration 31: MSE = 0.8049, m = 1.0963, b = 0.8260, dm = 0.0752, db = -0.3663
# Iteration 32: MSE = 0.8035, m = 1.0956, b = 0.8297, dm = 0.0822, db = -0.3627
# Iteration 33: MSE = 0.8021, m = 1.0948, b = 0.8333, dm = 0.0880, db = -0.3596
# Iteration 34: MSE = 0.8008, m = 1.0939, b = 0.8369, dm = 0.0928, db = -0.3568
# Iteration 35: MSE = 0.7994, m = 1.0930, b = 0.8405, dm = 0.0967, db = -0.3543
# Iteration 36: MSE = 0.7981, m = 1.0920, b = 0.8440, dm = 0.0999, db = -0.3520
# Iteration 37: MSE = 0.7967, m = 1.0910, b = 0.8475, dm = 0.1025, db = -0.3500
# Iteration 38: MSE = 0.7954, m = 1.0900, b = 0.8510, dm = 0.1047, db = -0.3481
# Iteration 39: MSE = 0.7941, m = 1.0889, b = 0.8545, dm = 0.1064, db = -0.3464
# Iteration 40: MSE = 0.7928, m = 1.0879, b = 0.8580, dm = 0.1077, db = -0.3448
# Iteration 41: MSE = 0.7915, m = 1.0868, b = 0.8614, dm = 0.1088, db = -0.3433
# Iteration 42: MSE = 0.7902, m = 1.0857, b = 0.8649, dm = 0.1097, db = -0.3418
# Iteration 43: MSE = 0.7889, m = 1.0846, b = 0.8683, dm = 0.1103, db = -0.3405
# Iteration 44: MSE = 0.7876, m = 1.0835, b = 0.8717, dm = 0.1108, db = -0.3392
# Iteration 45: MSE = 0.7863, m = 1.0824, b = 0.8751, dm = 0.1111, db = -0.3379
# Iteration 46: MSE = 0.7851, m = 1.0813, b = 0.8784, dm = 0.1113, db = -0.3367
# Iteration 47: MSE = 0.7838, m = 1.0802, b = 0.8818, dm = 0.1115, db = -0.3356
# Iteration 48: MSE = 0.7826, m = 1.0790, b = 0.8852, dm = 0.1115, db = -0.3344
# Iteration 49: MSE = 0.7813, m = 1.0779, b = 0.8885, dm = 0.1115, db = -0.3333
# Iteration 50: MSE = 0.7801, m = 1.0768, b = 0.8918, dm = 0.1115, db = -0.3322

# %%
plt.figure(figsize=(12, 7))

#Mean Squared Error (MSE) curve
plt.subplot(2, 2, 1)
plt.plot(iteration_list, mse_list, marker='o')
plt.xlabel('Iteration')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Gradient Descent for Linear Regression (MSE Curve)')
plt.grid(True)

#m and b values
plt.subplot(2, 2, 2)
plt.plot(iteration_list, m_new_list, label='m')
plt.plot(iteration_list, b_new_list, label='b')
plt.xlabel('Iteration')
plt.ylabel('Parameter Value')
plt.title('Parameter Update During Gradient Descent')
plt.legend()
plt.grid(True)

#dm and db values
plt.subplot(2, 2, 3)
plt.plot(iteration_list, dm_list, label='dm')
plt.plot(iteration_list, db_list, label='db')
plt.xlabel('Iteration')
plt.ylabel('Derivative Value')
plt.title('Derivative Update During Gradient Descent')
plt.legend()
plt.grid(True)

#predicted y values and data points
plt.subplot(2, 2, 4)
for i, y_pred in enumerate(y_pred_list):
    plt.plot([xi for xi, _ in data], y_pred, label=f'Iteration {i+1}')
for xi, yi in data:
    plt.scatter(xi, yi, color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Predicted y Values During Gradient Descent')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(iteration_list, mse_list, marker='o')
plt.xlabel('Iteration')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Gradient Descent for Linear Regression')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Example 2

# %%
data = [
    (1, 2),
    (2, 4),
    (3, 5),
    (4, 4)
]

# %%
m = 0.5
b = 0.5
learning_rate = 0.01
iterations = 15

# %%
iteration_list = []
mse_list = []
y_pred_list = []
dm_list = []
db_list = []
m_new_list = []
b_new_list = []

# %%
for iteration in range(iterations):
    #predicted values
    y_pred = [m * xi + b for xi, _ in data]
    
    #MSE
    mse = sum([(yi - ypi)**2 for (_, yi), ypi in zip(data, y_pred)]) / len(data)
    
    #derivatives
    dm = (-2/len(data)) * sum([xi * (yi - ypi) for (xi, yi), ypi in zip(data, y_pred)])
    db = (-2/len(data)) * sum([yi - ypi for (_, yi), ypi in zip(data, y_pred)])
    
    #Update m and b
    m_new = m - learning_rate * dm
    b_new = b - learning_rate * db
    
    #append values to lists
    iteration_list.append(iteration)
    mse_list.append(mse)
    y_pred_list.append(y_pred)
    dm_list.append(dm)
    db_list.append(db)
    m_new_list.append(m_new)
    b_new_list.append(b_new)

    #iteration details
    print(f"Iteration {iteration + 1}: MSE = {mse:.4f}, m = {m:.4f}, b = {b:.4f}, dm = {dm:.4f}, db = {db:.4f}")
    
    #Update m and b for the next iteration
    m = m_new
    b = b_new
# Out:
# Iteration 1: MSE = 4.6250, m = 0.5000, b = 0.5000, dm = -10.5000, db = -4.0000
# Iteration 2: MSE = 3.4678, m = 0.6050, b = 0.5400, dm = -8.7250, db = -3.3950
# Iteration 3: MSE = 2.6643, m = 0.6923, b = 0.5740, dm = -7.2465, db = -2.8908
# Iteration 4: MSE = 2.1063, m = 0.7647, b = 0.6029, dm = -6.0150, db = -2.4707
# Iteration 5: MSE = 1.7187, m = 0.8249, b = 0.6276, dm = -4.9892, db = -2.1205
# Iteration 6: MSE = 1.4492, m = 0.8748, b = 0.6488, dm = -4.1348, db = -1.8287
# Iteration 7: MSE = 1.2617, m = 0.9161, b = 0.6671, dm = -3.4231, db = -1.5854
# Iteration 8: MSE = 1.1312, m = 0.9503, b = 0.6829, dm = -2.8304, db = -1.3825
# Iteration 9: MSE = 1.0401, m = 0.9786, b = 0.6967, dm = -2.3367, db = -1.2133
# Iteration 10: MSE = 0.9764, m = 1.0020, b = 0.7089, dm = -1.9255, db = -1.0722
# Iteration 11: MSE = 0.9318, m = 1.0213, b = 0.7196, dm = -1.5831, db = -0.9545
# Iteration 12: MSE = 0.9003, m = 1.0371, b = 0.7291, dm = -1.2979, db = -0.8563
# Iteration 13: MSE = 0.8780, m = 1.0501, b = 0.7377, dm = -1.0604, db = -0.7742
# Iteration 14: MSE = 0.8621, m = 1.0607, b = 0.7454, dm = -0.8626, db = -0.7057
# Iteration 15: MSE = 0.8506, m = 1.0693, b = 0.7525, dm = -0.6980, db = -0.6485

# %%
plt.figure(figsize=(12, 7))
plt.subplot(2, 2, 1)
plt.plot(iteration_list, mse_list, marker='o')
plt.xlabel('Iteration')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Gradient Descent for Linear Regression (MSE Curve)')
plt.grid(True)

#plot m and b values
plt.subplot(2, 2, 2)
plt.plot(iteration_list, m_new_list, label='m')
plt.plot(iteration_list, b_new_list, label='b')
plt.xlabel('Iteration')
plt.ylabel('Parameter Value')
plt.title('Parameter Update During Gradient Descent')
plt.legend()
plt.grid(True)

#plot dm and db values
plt.subplot(2, 2, 3)
plt.plot(iteration_list, dm_list, label='dm')
plt.plot(iteration_list, db_list, label='db')
plt.xlabel('Iteration')
plt.ylabel('Derivative Value')
plt.title('Derivative Update During Gradient Descent')
plt.legend()
plt.grid(True)

#plot predicted y values and data points
plt.subplot(2, 2, 4)
for i, y_pred in enumerate(y_pred_list):
    plt.plot([xi for xi, _ in data], y_pred, label=f'Iteration {i+1}')
for xi, yi in data:
    plt.scatter(xi, yi, color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Predicted y Values During Gradient Descent')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Example 3

# %%
data = [
    (1, 2),
    (2, 4),
    (3, 5),
    (4, 4)
]

# %%
m = 0.5
b = 0.5
learning_rate = 0.01
iterations = 15

# %%
iteration_list = []
mse_list = []
y_pred_list = []

# %%
for iteration in range(iterations):
    #predicted values for this iteration
    y_pred_iteration = []  
    
    for xi, yi in data:
        #predicted value
        y_pred = m * xi + b
        y_pred_iteration.append(y_pred)
    
    y_pred_list.append(y_pred_iteration)
    
    #MSE
    mse = sum([(yi - ypi)**2 for yi, ypi in zip([y for _, y in data], y_pred_iteration)]) / len(data)
    
    # Calculate derivatives
    dm = (-2/len(data)) * sum([xi * (yi - ypi) for (xi, yi), ypi in zip(data, y_pred_iteration)])
    db = (-2/len(data)) * sum([yi - ypi for (_, yi), ypi in zip(data, y_pred_iteration)])
    
    #Update m and b
    if iteration > 0:  # Start updating from the second iteration
        m -= learning_rate * dm
        b -= learning_rate * db
    
    #append values to lists
    iteration_list.append(iteration)
    mse_list.append(mse)
    
    #iteration details
    if iteration == 0:
        print(f"Iteration {iteration + 1} - Initial values: m = {m:.3f}, b = {b:.3f}")
    else:
        print(f"Iteration {iteration + 1} - Updated values: m = {m:.3f}, b = {b:.3f}")
    print("Calculate predicted values y_pred:")
    
    for (xi, _), y_pred in zip(data, y_pred_iteration):
        y_pred_calc = m * xi + b 
        print(f"For ({xi}, {_}): y_pred = {m:.3f} * {xi} + {b:.3f} = {y_pred_calc:.3f}")
# Out:
# Iteration 1 - Initial values: m = 0.500, b = 0.500
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.500 * 1 + 0.500 = 1.000
# For (2, 4): y_pred = 0.500 * 2 + 0.500 = 1.500
# For (3, 5): y_pred = 0.500 * 3 + 0.500 = 2.000
# For (4, 4): y_pred = 0.500 * 4 + 0.500 = 2.500
# Iteration 2 - Updated values: m = 0.605, b = 0.540
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.605 * 1 + 0.540 = 1.145
# For (2, 4): y_pred = 0.605 * 2 + 0.540 = 1.750
# For (3, 5): y_pred = 0.605 * 3 + 0.540 = 2.355
# For (4, 4): y_pred = 0.605 * 4 + 0.540 = 2.960
# Iteration 3 - Updated values: m = 0.692, b = 0.574
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.692 * 1 + 0.574 = 1.266
# For (2, 4): y_pred = 0.692 * 2 + 0.574 = 1.958
# For (3, 5): y_pred = 0.692 * 3 + 0.574 = 2.651
# For (4, 4): y_pred = 0.692 * 4 + 0.574 = 3.343
# Iteration 4 - Updated values: m = 0.765, b = 0.603
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.765 * 1 + 0.603 = 1.368
# For (2, 4): y_pred = 0.765 * 2 + 0.603 = 2.132
# For (3, 5): y_pred = 0.765 * 3 + 0.603 = 2.897
# For (4, 4): y_pred = 0.765 * 4 + 0.603 = 3.662
# Iteration 5 - Updated values: m = 0.825, b = 0.628
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.825 * 1 + 0.628 = 1.452
# For (2, 4): y_pred = 0.825 * 2 + 0.628 = 2.277
# For (3, 5): y_pred = 0.825 * 3 + 0.628 = 3.102
# For (4, 4): y_pred = 0.825 * 4 + 0.628 = 3.927
# Iteration 6 - Updated values: m = 0.875, b = 0.649
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.875 * 1 + 0.649 = 1.524
# For (2, 4): y_pred = 0.875 * 2 + 0.649 = 2.398
# For (3, 5): y_pred = 0.875 * 3 + 0.649 = 3.273
# For (4, 4): y_pred = 0.875 * 4 + 0.649 = 4.148
# Iteration 7 - Updated values: m = 0.916, b = 0.667
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.916 * 1 + 0.667 = 1.583
# For (2, 4): y_pred = 0.916 * 2 + 0.667 = 2.499
# For (3, 5): y_pred = 0.916 * 3 + 0.667 = 3.415
# For (4, 4): y_pred = 0.916 * 4 + 0.667 = 4.331
# Iteration 8 - Updated values: m = 0.950, b = 0.683
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.950 * 1 + 0.683 = 1.633
# For (2, 4): y_pred = 0.950 * 2 + 0.683 = 2.584
# For (3, 5): y_pred = 0.950 * 3 + 0.683 = 3.534
# For (4, 4): y_pred = 0.950 * 4 + 0.683 = 4.484
# Iteration 9 - Updated values: m = 0.979, b = 0.697
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 0.979 * 1 + 0.697 = 1.675
# For (2, 4): y_pred = 0.979 * 2 + 0.697 = 2.654
# For (3, 5): y_pred = 0.979 * 3 + 0.697 = 3.633
# For (4, 4): y_pred = 0.979 * 4 + 0.697 = 4.611
# Iteration 10 - Updated values: m = 1.002, b = 0.709
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 1.002 * 1 + 0.709 = 1.711
# For (2, 4): y_pred = 1.002 * 2 + 0.709 = 2.713
# For (3, 5): y_pred = 1.002 * 3 + 0.709 = 3.715
# For (4, 4): y_pred = 1.002 * 4 + 0.709 = 4.717
# Iteration 11 - Updated values: m = 1.021, b = 0.720
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 1.021 * 1 + 0.720 = 1.741
# For (2, 4): y_pred = 1.021 * 2 + 0.720 = 2.762
# For (3, 5): y_pred = 1.021 * 3 + 0.720 = 3.783
# For (4, 4): y_pred = 1.021 * 4 + 0.720 = 4.805
# Iteration 12 - Updated values: m = 1.037, b = 0.729
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 1.037 * 1 + 0.729 = 1.766
# For (2, 4): y_pred = 1.037 * 2 + 0.729 = 2.803
# For (3, 5): y_pred = 1.037 * 3 + 0.729 = 3.840
# For (4, 4): y_pred = 1.037 * 4 + 0.729 = 4.878
# Iteration 13 - Updated values: m = 1.050, b = 0.738
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 1.050 * 1 + 0.738 = 1.788
# For (2, 4): y_pred = 1.050 * 2 + 0.738 = 2.838
# For (3, 5): y_pred = 1.050 * 3 + 0.738 = 3.888
# For (4, 4): y_pred = 1.050 * 4 + 0.738 = 4.938
# Iteration 14 - Updated values: m = 1.061, b = 0.745
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 1.061 * 1 + 0.745 = 1.806
# For (2, 4): y_pred = 1.061 * 2 + 0.745 = 2.867
# For (3, 5): y_pred = 1.061 * 3 + 0.745 = 3.927
# For (4, 4): y_pred = 1.061 * 4 + 0.745 = 4.988
# Iteration 15 - Updated values: m = 1.069, b = 0.752
# Calculate predicted values y_pred:
# For (1, 2): y_pred = 1.069 * 1 + 0.752 = 1.822
# For (2, 4): y_pred = 1.069 * 2 + 0.752 = 2.891
# For (3, 5): y_pred = 1.069 * 3 + 0.752 = 3.960
# For (4, 4): y_pred = 1.069 * 4 + 0.752 = 5.030
